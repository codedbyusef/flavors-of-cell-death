# %%
library(RadioGx)
# Out:
# Loading required package: CoreGx
#
# Loading required package: BiocGenerics
#
# Loading required package: generics
#
#
# Attaching package: ‘generics’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# ...

# %%
dir.create("../data")

# %%
# Download the dataset to folder
cleveland_dataset <- downloadRSet("Cleveland", saveDir="../data/")

# Extract the RNA matrix
rna_matrix <- molecularProfiles(cleveland_dataset, "rnaseq")

# Print the dimensions (Rows = Genes, Columns = Cell Lines)
print(dim(rna_matrix))
# Out:
# [1] 61958   513

# %%
# Sample
head(rna_matrix)
# Out:
#                 G20461.HSC-3.2 G20463.C2BBe1.2 G20466.5637.2 G20468.DMS_53.2
# ENSG00000000003 4.527          5.860           5.394         3.931
# ENSG00000000005 0.000          0.070           0.000         0.000
# ENSG00000000419 6.314          7.303           6.140         5.297
# ENSG00000000457 2.260          1.978           1.876         2.408
# ENSG00000000460 4.334          3.897           4.551         3.670
# ENSG00000000938 0.025          0.029           0.139         0.000
#                 G20469.JHOS-2.2 G20471.Daoy.2 G20472.CHP-212.2 G20474.Hs_746T.2
# ENSG00000000003 6.136           4.586         4.206            3.976
# ENSG00000000005 0.000           0.000         0.000            0.032
# ENSG00000000419 5.982           5.524         5.347            6.250
# ENSG00000000457 2.593           2.163         3.024            1.879
# ENSG00000000460 4.129           4.537         3.906            3.615
# ...

# %%
# Get sample metadata
phenoInf <- phenoInfo(cleveland_dataset, 'cnv')

# Get feature metadata
featInfo <- featureInfo(cleveland_dataset, 'rnaseq')

# %%
summary(as.vector(rna_matrix[, 1:2]))
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.0000  0.0000  0.0000  0.8261  0.3180 14.8160
